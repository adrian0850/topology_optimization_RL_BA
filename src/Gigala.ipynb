# %% [markdown]
# Here the reward for each state of the workspace is

# %%
import time
import os
import random
import numpy as np                                                
import matplotlib.pyplot as plt                                   
import autograd, autograd.core, autograd.extend, autograd.tracer  
import autograd.numpy as anp      
import scipy, scipy.ndimage, scipy.sparse, scipy.sparse.linalg 

import torch 
                                                     
import gymnasium as gym
# from gym import spaces
from gymnasium import spaces

from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import results_plotter

# %%
# !pip3 install --upgrade stable_baselines3
# !pip3 install gym==0.22.0

# %% [markdown]
# The below code is my RL extension to and rework of https://www.researchgate.net/publication/360698153_A_Tutorial_on_Structural_Optimization
# and
# https://www.sciencedirect.com/science/article/pii/S0264127522002933

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d
    
def get_args(normals, forces, density=1e-4):  # Manage the problem setup parameters
    width = normals.shape[0] - 1
    height = normals.shape[1] - 1
    fixdofs = np.flatnonzero(normals.ravel())
    alldofs = np.arange(2 * (width + 1) * (height + 1))
    freedofs = np.sort(list(set(alldofs) - set(fixdofs)))
    params = {
      # material properties
      'young': 1, 'young_min': 1e-9, 'poisson': 0.3, 'g': 0,
      # constraints
      'density': density, 'xmin': 0.001, 'xmax': 1.0,
      # input parameters
      'nelx': width, 'nely': height, 'mask': 1, 'penal': 3.0, 'filter_width': 1,
      'freedofs': freedofs, 'fixdofs': fixdofs, 'forces': forces.ravel(),
      # optimization parameters
      'opt_steps': 80, 'print_every': 10}
    return ObjectView(params)

def mbb_beam(width=7, height=7, density=1e-4, y=1, x=0, rd=-1):  # textbook beam example
    normals = np.zeros((width + 1, height + 1, 2))
    normals[0, 0, x] = 1
    normals[0, 0, y] = 1
    normals[0, -1, x] = 1
    normals[0, -1, y] = 1
    forces = np.zeros((width + 1, height + 1, 2))
    forces[-1, rd, y] = -1
    return normals, forces, density

# %%
def young_modulus(x, e_0, e_min, p=3):
    return e_min + x ** p * (e_0 - e_min)

def physical_density(x, args, volume_contraint=False, use_filter=True):
    x = args.mask * x.reshape(args.nely, args.nelx)  # reshape from 1D to 2D
    return gaussian_filter(x, args.filter_width) if use_filter else x  # maybe filter

def mean_density(x, args, volume_contraint=False, use_filter=True):
    return anp.mean(physical_density(x, args, volume_contraint, use_filter)) / anp.mean(args.mask)

# %% [markdown]
# ke = stiffnes matrix
# u = displacement matrix
#
# $compliance =

# %%
def objective(x, args, volume_contraint=False, use_filter=True):
    kwargs = dict(penal=args.penal, e_min=args.young_min, e_0=args.young)
    x_phys = physical_density(x, args, volume_contraint=volume_contraint, use_filter=use_filter)
    ke     = get_stiffness_matrix(args.young, args.poisson)  # stiffness matrix
    u      = displace(x_phys, ke, args.forces, args.freedofs, args.fixdofs, **kwargs)
    c      = compliance(x_phys, u, ke, **kwargs)
    return c

# %% [markdown]
# ```Compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1)```
#
# This Python function, compliance, calculates the compliance of a structure given its physical density (x_phys), displacement (u), and stiffness matrix (ke). The compliance of a structure is a measure of its flexibility, and it's often used in structural optimization problems.
#
# Here's a step-by-step explanation of the code:
#
# ```nely, nelx = x_phys.shape```: This line gets the shape of the x_phys array, which represents the physical density of the structure. nely and nelx are the number of elements in the y and x directions, respectively.
#
# ```ely, elx = anp.meshgrid(range(nely), range(nelx))```: This line creates a grid of y and x coordinates for the index map.
#
# The next four lines calculate the node numbers for each element in the structure. Each element is assumed to be a quadrilateral with four nodes.
#
# ```all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])```: This line creates an array of indices to select the displacement values from the u matrix for each node of each element.
#
# ```u_selected = u[all_ixs]```: This line selects the displacement values for each node of each element from the u matrix.
#
# ```ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)```: This line computes the product of the stiffness matrix ke and the selected displacement values u_selected.
#
# ```ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)```: This line computes the element-wise product of u_selected and ke_u, and then sums over the first dimension.
#
# ```C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T```: This line calculates the compliance of each element by multiplying the Young's modulus of each element (calculated by the young_modulus function) with ce.T (the transpose of ce).
#
# ```return anp.sum(C)```: This line sums up the compliance of all elements to get the total compliance of the structure, and returns this value.

# %%
def compliance(x_phys, u, ke, *, penal=3, e_min=1e-9, e_0=1):
    nely, nelx = x_phys.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords for the index map

    n1 = (nely+1)*(elx+0) + (ely+0)  # nodes
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    all_ixs = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    u_selected = u[all_ixs]  # select from u matrix

    ke_u = anp.einsum('ij,jkl->ikl', ke, u_selected)  # compute x^penal * U.T @ ke @ U
    ce = anp.einsum('ijk,ijk->jk', u_selected, ke_u)
    C = young_modulus(x_phys, e_0, e_min, p=penal) * ce.T
    return anp.sum(C)

def get_stiffness_matrix(e, nu):  # e=young's modulus, nu=poisson coefficient
    k = anp.array([1/2-nu/6, 1/8+nu/8, -1/4-nu/12, -1/8+3*nu/8,
                -1/4+nu/12, -1/8-nu/8, nu/6, 1/8-3*nu/8])
    return e/(1-nu**2)*anp.array([[k[0], k[1], k[2], k[3], k[4], k[5], k[6], k[7]],
                               [k[1], k[0], k[7], k[6], k[5], k[4], k[3], k[2]],
                               [k[2], k[7], k[0], k[5], k[6], k[3], k[4], k[1]],
                               [k[3], k[6], k[5], k[0], k[7], k[2], k[1], k[4]],
                               [k[4], k[5], k[6], k[7], k[0], k[1], k[2], k[3]],
                               [k[5], k[4], k[3], k[2], k[1], k[0], k[7], k[6]],
                               [k[6], k[3], k[4], k[1], k[2], k[7], k[0], k[5]],
                               [k[7], k[2], k[1], k[4], k[3], k[6], k[5], k[0]]])

# %%
# @autograd.extend.primitive
def gaussian_filter(x, width): # 2D gaussian blur/filter
    return scipy.ndimage.gaussian_filter(x, width, mode='reflect')

def _gaussian_filter_vjp(ans, x, width): # gives the gradient of orig. function w.r.t. x
    del ans, x  # unused
    return lambda g: gaussian_filter(g, width)
# autograd.extend.defvjp(gaussian_filter, _gaussian_filter_vjp)

# %%
def get_k(stiffness, ke):
    # Constructs sparse stiffness matrix k (used in the displace fn)
    # First, get position of the nodes of each element in the stiffness matrix
    nely, nelx = stiffness.shape
    ely, elx = anp.meshgrid(range(nely), range(nelx))  # x, y coords
    ely, elx = ely.reshape(-1, 1), elx.reshape(-1, 1)

    n1 = (nely+1)*(elx+0) + (ely+0)
    n2 = (nely+1)*(elx+1) + (ely+0)
    n3 = (nely+1)*(elx+1) + (ely+1)
    n4 = (nely+1)*(elx+0) + (ely+1)
    edof = anp.array([2*n1, 2*n1+1, 2*n2, 2*n2+1, 2*n3, 2*n3+1, 2*n4, 2*n4+1])
    edof = edof.T[0]
    x_list = anp.repeat(edof, 8)  # flat list pointer of each node in an element
    y_list = anp.tile(edof, 8).flatten()  # flat list pointer of each node in elem

    # make the global stiffness matrix K
    kd = stiffness.T.reshape(nelx*nely, 1, 1)
    value_list = (kd * anp.tile(ke, kd.shape)).flatten()
    return value_list, y_list, x_list

def displace(x_phys, ke, forces, freedofs, fixdofs, *, penal=3, e_min=1e-9, e_0=1):
    # Displaces the load x using finite element techniques (solve_coo=most of runtime)
    stiffness = young_modulus(x_phys, e_0, e_min, p=penal)
    k_entries, k_ylist, k_xlist = get_k(stiffness, ke)

    index_map, keep, indices = _get_dof_indices(freedofs, fixdofs, k_ylist, k_xlist)

    u_nonzero = solve_coo(k_entries[keep], indices, forces[freedofs], sym_pos=True)
    u_values = anp.concatenate([u_nonzero, anp.zeros(len(fixdofs))])
    return u_values[index_map]

# %%
def _get_dof_indices(freedofs, fixdofs, k_xlist, k_ylist):
    index_map = inverse_permutation(anp.concatenate([freedofs, fixdofs]))
    keep = anp.isin(k_xlist, freedofs) & anp.isin(k_ylist, freedofs)
    # Now we index an indexing array that is being indexed by the indices of k
    i = index_map[k_ylist][keep]
    j = index_map[k_xlist][keep]
    return index_map, keep, anp.stack([i, j])

def inverse_permutation(indices):  # reverses an index operation
    inverse_perm = np.zeros(len(indices), dtype=anp.int64)
    inverse_perm[indices] = np.arange(len(indices), dtype=anp.int64)
    return inverse_perm

# %%
def _get_solver(a_entries, a_indices, size, sym_pos):
    # a is (usu.) symmetric positive; could solve 2x faster w/sksparse.cholmod.cholesky(a).solve_A
    a = scipy.sparse.coo_matrix((a_entries, a_indices), shape=(size,)*2).tocsc()
    return scipy.sparse.linalg.splu(a).solve

# @autograd.primitive
def solve_coo(a_entries, a_indices, b, sym_pos=False):
    solver = _get_solver(a_entries, a_indices, b.size, sym_pos)
    return solver(b)

def grad_solve_coo_entries(ans, a_entries, a_indices, b, sym_pos=False):
    def jvp(grad_ans):
        lambda_ = solve_coo(a_entries, a_indices if sym_pos else a_indices[::-1],
                            grad_ans, sym_pos)
        i, j = a_indices
        return -lambda_[i] * ans[j]
    return jvp

# autograd.extend.defvjp(solve_coo, grad_solve_coo_entries,
#                        lambda: print('err: gradient undefined'),
#                        lambda: print('err: gradient not implemented'))

# %%
class Model:
    def __init__(self, x):
        self.flag_ = True
#         self.flag_ = False
        #x = 2d Array with each element = args.density
        self.n, self.m = x.shape
        self.actions_dic={}
    
        k=0
        for i in range(self.n):
            for j in range(self.m):
                self.actions_dic[k]=(i,j)
                k+=1
        print('actions_dic:',self.actions_dic)
    
    
    
    def action_space_(self, action, X):
        x,y=self.actions_dic[action]
        X[x][y]=1
        
    def draw(self,X):  
        plt.figure(dpi=50) 
        print('\nFinal Cantilever beam design:')
        plt.imshow(X) 
        plt.show()

# %% [markdown]
# the actionspace of the Model is a Dictionary of length self.n*self.m with each entry corresponding to a coordinate (x,y):
#
# 1:  (0,0) 2:(0,1)......... n(x,y)
#
# Actions get done by selecting an integer action wih value between 0 and x*y and turning the element at that specific coordinate to a 1

# %%
def fast_stopt(args, x):

    reshape = lambda x: x.reshape(args.nely, args.nelx)
    objective_fn = lambda x: objective(reshape(x), args)
#     constraint = lambda params: mean_density(reshape(params), args) - args.density
    constraint = lambda params: mean_density(reshape(params), args) 
    value = objective_fn(x)
    const = constraint(x)
    return value, const

# %%
class CantileverEnv(gym.Env):
    
    metadata = {"render.modes": ["human"]}

    def __init__(self):
        super().__init__()
        
        
        self.rd=0
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        DIM=self.args.nelx*self.args.nely
        N_DISCRETE_ACTIONS=self.args.nelx*self.args.nely
        
        self.action_space = spaces.Discrete(N_DISCRETE_ACTIONS)
        self.observation_space = spaces.Box(low=np.array([-1e10 for x in range(DIM)]),
                                            high=np.array([1e10 for y in range(DIM)]),
                                            shape=(DIM,),
                                           dtype=np.float64)
        
 
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 
    
        self.M=Model(self.x)
        
        self.reward=0
        self.step_=0
        self.needs_reset = True
#         self.seed=0
        
    def step(self, action):
        
        self.args = get_args(*mbb_beam(rd=self.rd))
        
        self.M.action_space_(action, self.x)
        
        self.tmp, self.const = fast_stopt(self.args, self.x)
#         print(tmp, const)
        
        self.step_+=1
        
#         self.reward+=(1/self.tmp)**2
#         self.reward=(1/self.tmp)**2
        self.reward +=(1/self.tmp)**0.5

       
        done=False
                  
        if self.step_>self.M.n*self.M.m:
            done=True
            
        if self.const>0.7:
#             self.reward-=1
            done=True
            
        if self.needs_reset:
            raise RuntimeError("Tried to step environment that needs reset")
            
        if done:
            self.needs_reset = True
                         
      
        return self.x.reshape(self.x.shape[0]*self.x.shape[1]), self.reward, done,False, dict()

    def reset(self, seed=0):
        
        if not self.M.flag_:
            self.rd=random.choice([0,2,-2])
        else:
            self.rd=-1
           
        self.x = anp.ones((self.args.nely, self.args.nelx))*self.args.density 

        self.reward=0
        self.needs_reset = False
        self.step_=0

        return self.x.reshape(self.x.shape[0]*self.x.shape[1]),{}

    def render(self, mode="human"):
        self.M.draw(self.x)    

    def close(self):
        pass

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# ts=5e6
ts=1e6

# %%
# Create log dir
log_dir = "log"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = CantileverEnv()
# Logs will be saved in log_dir/monitor.csv

env = Monitor(env, log_dir)
check_env(env)
# Out:
# actions_dic: {0: (0, 0), 1: (0, 1), 2: (0, 2), 3: (0, 3), 4: (0, 4), 5: (0, 5), 6: (0, 6), 7: (1, 0), 8: (1, 1), 9: (1, 2), 10: (1, 3), 11: (1, 4), 12: (1, 5), 13: (1, 6), 14: (2, 0), 15: (2, 1), 16: (2, 2), 17: (2, 3), 18: (2, 4), 19: (2, 5), 20: (2, 6), 21: (3, 0), 22: (3, 1), 23: (3, 2), 24: (3, 3), 25: (3, 4), 26: (3, 5), 27: (3, 6), 28: (4, 0), 29: (4, 1), 30: (4, 2), 31: (4, 3), 32: (4, 4), 33: (4, 5), 34: (4, 6), 35: (5, 0), 36: (5, 1), 37: (5, 2), 38: (5, 3), 39: (5, 4), 40: (5, 5), 41: (5, 6), 42: (6, 0), 43: (6, 1), 44: (6, 2), 45: (6, 3), 46: (6, 4), 47: (6, 5), 48: (6, 6)}

# %%
# callback = SaveOnBestTrainingRewardCallback(check_freq=5000, log_dir=log_dir)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

# %%
start=time.time()
model = PPO("MlpPolicy", env).learn(total_timesteps=ts, callback=callback)
end=time.time()
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 27.97
# Saving new best model to log\best_model.zip
# Num timesteps: 2000
# Best mean reward: 27.97 - Last mean reward per episode: 26.79
# Num timesteps: 3000
# Best mean reward: 27.97 - Last mean reward per episode: 27.15
# Num timesteps: 4000
# Best mean reward: 27.97 - Last mean reward per episode: 28.47
# Saving new best model to log\best_model.zip
# Num timesteps: 5000
# Best mean reward: 28.47 - Last mean reward per episode: 28.82
# Saving new best model to log\best_model.zip
# Num timesteps: 6000
# Best mean reward: 28.82 - Last mean reward per episode: 28.69
# Num timesteps: 7000
# Best mean reward: 28.82 - Last mean reward per episode: 29.58
# Saving new best model to log\best_model.zip
# Num timesteps: 8000
# Best mean reward: 29.58 - Last mean reward per episode: 30.52
# Saving new best model to log\best_model.zip
# Num timesteps: 9000
# Best mean reward: 30.52 - Last mean reward per episode: 29.72
# Num timesteps: 10000
# Best mean reward: 30.52 - Last mean reward per episode: 29.92
# Num timesteps: 11000
# Best mean reward: 30.52 - Last mean reward per episode: 30.71
# Saving new best model to log\best_model.zip
# Num timesteps: 12000
# Best mean reward: 30.71 - Last mean reward per episode: 31.88
# Saving new best model to log\best_model.zip
# Num timesteps: 13000
# Best mean reward: 31.88 - Last mean reward per episode: 32.27
# Saving new best model to log\best_model.zip
# Num timesteps: 14000
# Best mean reward: 32.27 - Last mean reward per episode: 33.55
# Saving new best model to log\best_model.zip
# Num timesteps: 15000
# Best mean reward: 33.55 - Last mean reward per episode: 35.15
# Saving new best model to log\best_model.zip
# Num timesteps: 16000
# Best mean reward: 35.15 - Last mean reward per episode: 36.44
# Saving new best model to log\best_model.zip
# Num timesteps: 17000
# Best mean reward: 36.44 - Last mean reward per episode: 37.37
# Saving new best model to log\best_model.zip
# Num timesteps: 18000
# Best mean reward: 37.37 - Last mean reward per episode: 38.96
# Saving new best model to log\best_model.zip
# Num timesteps: 19000
# Best mean reward: 38.96 - Last mean reward per episode: 40.68
# Saving new best model to log\best_model.zip
# Num timesteps: 20000
# Best mean reward: 40.68 - Last mean reward per episode: 40.53
# Num timesteps: 21000
# Best mean reward: 40.68 - Last mean reward per episode: 41.51
# Saving new best model to log\best_model.zip
# Num timesteps: 22000
# Best mean reward: 41.51 - Last mean reward per episode: 43.00
# Saving new best model to log\best_model.zip
# Num timesteps: 23000
# Best mean reward: 43.00 - Last mean reward per episode: 43.43
# Saving new best model to log\best_model.zip
# Num timesteps: 24000
# Best mean reward: 43.43 - Last mean reward per episode: 43.13
# Num timesteps: 25000
# Best mean reward: 43.43 - Last mean reward per episode: 44.86
# Saving new best model to log\best_model.zip
# Num timesteps: 26000
# Best mean reward: 44.86 - Last mean reward per episode: 45.20
# Saving new best model to log\best_model.zip
# Num timesteps: 27000
# Best mean reward: 45.20 - Last mean reward per episode: 44.00
# Num timesteps: 28000
# Best mean reward: 45.20 - Last mean reward per episode: 44.35
# Num timesteps: 29000
# Best mean reward: 45.20 - Last mean reward per episode: 44.58
# Num timesteps: 30000
# Best mean reward: 45.20 - Last mean reward per episode: 43.67
# Num timesteps: 31000
# Best mean reward: 45.20 - Last mean reward per episode: 42.81
# Num timesteps: 32000
# Best mean reward: 45.20 - Last mean reward per episode: 43.55
# Num timesteps: 33000
# Best mean reward: 45.20 - Last mean reward per episode: 42.89
# Num timesteps: 34000
# Best mean reward: 45.20 - Last mean reward per episode: 43.51
# Num timesteps: 35000
# Best mean reward: 45.20 - Last mean reward per episode: 43.88
# Num timesteps: 36000
# Best mean reward: 45.20 - Last mean reward per episode: 44.86
# Num timesteps: 37000
# Best mean reward: 45.20 - Last mean reward per episode: 44.72
# Num timesteps: 38000
# Best mean reward: 45.20 - Last mean reward per episode: 46.16
# Saving new best model to log\best_model.zip
# Num timesteps: 39000
# Best mean reward: 46.16 - Last mean reward per episode: 45.41
# Num timesteps: 40000
# Best mean reward: 46.16 - Last mean reward per episode: 45.67
# Num timesteps: 41000
# Best mean reward: 46.16 - Last mean reward per episode: 45.82
# Num timesteps: 42000
# Best mean reward: 46.16 - Last mean reward per episode: 46.59
# Saving new best model to log\best_model.zip
# Num timesteps: 43000
# Best mean reward: 46.59 - Last mean reward per episode: 44.86
# Num timesteps: 44000
# Best mean reward: 46.59 - Last mean reward per episode: 45.61
# Num timesteps: 45000
# Best mean reward: 46.59 - Last mean reward per episode: 46.18
# Num timesteps: 46000
# Best mean reward: 46.59 - Last mean reward per episode: 46.91
# Saving new best model to log\best_model.zip
# Num timesteps: 47000
# Best mean reward: 46.91 - Last mean reward per episode: 47.01
# Saving new best model to log\best_model.zip
# Num timesteps: 48000
# Best mean reward: 47.01 - Last mean reward per episode: 47.20
# Saving new best model to log\best_model.zip
# Num timesteps: 49000
# Best mean reward: 47.20 - Last mean reward per episode: 47.87
# Saving new best model to log\best_model.zip
# Num timesteps: 50000
# Best mean reward: 47.87 - Last mean reward per episode: 47.24
# Num timesteps: 51000
# Best mean reward: 47.87 - Last mean reward per episode: 46.21
# Num timesteps: 52000
# Best mean reward: 47.87 - Last mean reward per episode: 45.07
# Num timesteps: 53000
# Best mean reward: 47.87 - Last mean reward per episode: 46.05
# Num timesteps: 54000
# Best mean reward: 47.87 - Last mean reward per episode: 45.82
# Num timesteps: 55000
# Best mean reward: 47.87 - Last mean reward per episode: 46.08
# Num timesteps: 56000
# Best mean reward: 47.87 - Last mean reward per episode: 47.25
# Num timesteps: 57000
# Best mean reward: 47.87 - Last mean reward per episode: 48.26
# Saving new best model to log\best_model.zip
# Num timesteps: 58000
# Best mean reward: 48.26 - Last mean reward per episode: 47.64
# Num timesteps: 59000
# Best mean reward: 48.26 - Last mean reward per episode: 48.17
# Num timesteps: 60000
# Best mean reward: 48.26 - Last mean reward per episode: 48.23
# Num timesteps: 61000
# Best mean reward: 48.26 - Last mean reward per episode: 48.33
# Saving new best model to log\best_model.zip
# Num timesteps: 62000
# Best mean reward: 48.33 - Last mean reward per episode: 48.11
# Num timesteps: 63000
# Best mean reward: 48.33 - Last mean reward per episode: 49.17
# Saving new best model to log\best_model.zip
# Num timesteps: 64000
# Best mean reward: 49.17 - Last mean reward per episode: 48.46
# Num timesteps: 65000
# Best mean reward: 49.17 - Last mean reward per episode: 48.23
# Num timesteps: 66000
# Best mean reward: 49.17 - Last mean reward per episode: 48.03
# Num timesteps: 67000
# Best mean reward: 49.17 - Last mean reward per episode: 48.46
# Num timesteps: 68000
# Best mean reward: 49.17 - Last mean reward per episode: 47.89
# Num timesteps: 69000
# Best mean reward: 49.17 - Last mean reward per episode: 48.13
# Num timesteps: 70000
# Best mean reward: 49.17 - Last mean reward per episode: 48.49
# Num timesteps: 71000
# Best mean reward: 49.17 - Last mean reward per episode: 47.68
# Num timesteps: 72000
# Best mean reward: 49.17 - Last mean reward per episode: 47.35
# Num timesteps: 73000
# Best mean reward: 49.17 - Last mean reward per episode: 47.64
# Num timesteps: 74000
# Best mean reward: 49.17 - Last mean reward per episode: 47.20
# Num timesteps: 75000
# Best mean reward: 49.17 - Last mean reward per episode: 47.61
# Num timesteps: 76000
# Best mean reward: 49.17 - Last mean reward per episode: 48.75
# Num timesteps: 77000
# Best mean reward: 49.17 - Last mean reward per episode: 48.43
# Num timesteps: 78000
# Best mean reward: 49.17 - Last mean reward per episode: 48.24
# Num timesteps: 79000
# Best mean reward: 49.17 - Last mean reward per episode: 48.54
# Num timesteps: 80000
# Best mean reward: 49.17 - Last mean reward per episode: 47.79
# Num timesteps: 81000
# Best mean reward: 49.17 - Last mean reward per episode: 46.78
# Num timesteps: 82000
# Best mean reward: 49.17 - Last mean reward per episode: 47.04
# Num timesteps: 83000
# Best mean reward: 49.17 - Last mean reward per episode: 47.52
# Num timesteps: 84000
# Best mean reward: 49.17 - Last mean reward per episode: 47.85
# Num timesteps: 85000
# Best mean reward: 49.17 - Last mean reward per episode: 47.62
# Num timesteps: 86000
# Best mean reward: 49.17 - Last mean reward per episode: 47.75
# Num timesteps: 87000
# Best mean reward: 49.17 - Last mean reward per episode: 47.91
# Num timesteps: 88000
# Best mean reward: 49.17 - Last mean reward per episode: 46.87
# Num timesteps: 89000
# Best mean reward: 49.17 - Last mean reward per episode: 46.17
# Num timesteps: 90000
# Best mean reward: 49.17 - Last mean reward per episode: 46.51
# Num timesteps: 91000
# Best mean reward: 49.17 - Last mean reward per episode: 46.61
# Num timesteps: 92000
# Best mean reward: 49.17 - Last mean reward per episode: 46.57
# Num timesteps: 93000
# Best mean reward: 49.17 - Last mean reward per episode: 46.98
# Num timesteps: 94000
# Best mean reward: 49.17 - Last mean reward per episode: 48.28
# Num timesteps: 95000
# Best mean reward: 49.17 - Last mean reward per episode: 48.52
# Num timesteps: 96000
# Best mean reward: 49.17 - Last mean reward per episode: 48.08
# Num timesteps: 97000
# Best mean reward: 49.17 - Last mean reward per episode: 48.78
# Num timesteps: 98000
# Best mean reward: 49.17 - Last mean reward per episode: 49.13
# Num timesteps: 99000
# Best mean reward: 49.17 - Last mean reward per episode: 47.85
# Num timesteps: 100000
# Best mean reward: 49.17 - Last mean reward per episode: 47.03
# Num timesteps: 101000
# Best mean reward: 49.17 - Last mean reward per episode: 48.07
# Num timesteps: 102000
# Best mean reward: 49.17 - Last mean reward per episode: 46.35
# Num timesteps: 103000
# Best mean reward: 49.17 - Last mean reward per episode: 45.79
# Num timesteps: 104000
# Best mean reward: 49.17 - Last mean reward per episode: 45.88
# Num timesteps: 105000
# Best mean reward: 49.17 - Last mean reward per episode: 46.31
# Num timesteps: 106000
# Best mean reward: 49.17 - Last mean reward per episode: 45.18
# Num timesteps: 107000
# Best mean reward: 49.17 - Last mean reward per episode: 45.89
# Num timesteps: 108000
# Best mean reward: 49.17 - Last mean reward per episode: 45.52
# Num timesteps: 109000
# Best mean reward: 49.17 - Last mean reward per episode: 44.75
# Num timesteps: 110000
# Best mean reward: 49.17 - Last mean reward per episode: 44.51
# Num timesteps: 111000
# Best mean reward: 49.17 - Last mean reward per episode: 44.16
# Num timesteps: 112000
# Best mean reward: 49.17 - Last mean reward per episode: 43.80
# Num timesteps: 113000
# Best mean reward: 49.17 - Last mean reward per episode: 43.45
# Num timesteps: 114000
# Best mean reward: 49.17 - Last mean reward per episode: 43.38
# Num timesteps: 115000
# Best mean reward: 49.17 - Last mean reward per episode: 42.99
# Num timesteps: 116000
# Best mean reward: 49.17 - Last mean reward per episode: 43.59
# Num timesteps: 117000
# Best mean reward: 49.17 - Last mean reward per episode: 43.27
# Num timesteps: 118000
# Best mean reward: 49.17 - Last mean reward per episode: 44.02
# Num timesteps: 119000
# Best mean reward: 49.17 - Last mean reward per episode: 43.84
# Num timesteps: 120000
# Best mean reward: 49.17 - Last mean reward per episode: 43.71
# Num timesteps: 121000
# Best mean reward: 49.17 - Last mean reward per episode: 42.41
# Num timesteps: 122000
# Best mean reward: 49.17 - Last mean reward per episode: 42.13
# Num timesteps: 123000
# Best mean reward: 49.17 - Last mean reward per episode: 40.56
# Num timesteps: 124000
# Best mean reward: 49.17 - Last mean reward per episode: 39.99
# Num timesteps: 125000
# Best mean reward: 49.17 - Last mean reward per episode: 40.32
# Num timesteps: 126000
# Best mean reward: 49.17 - Last mean reward per episode: 41.19
# Num timesteps: 127000
# Best mean reward: 49.17 - Last mean reward per episode: 40.98
# Num timesteps: 128000
# Best mean reward: 49.17 - Last mean reward per episode: 41.94
# Num timesteps: 129000
# Best mean reward: 49.17 - Last mean reward per episode: 42.47
# Num timesteps: 130000
# Best mean reward: 49.17 - Last mean reward per episode: 41.34
# Num timesteps: 131000
# Best mean reward: 49.17 - Last mean reward per episode: 41.08
# Num timesteps: 132000
# Best mean reward: 49.17 - Last mean reward per episode: 40.78
# Num timesteps: 133000
# Best mean reward: 49.17 - Last mean reward per episode: 40.18
# Num timesteps: 134000
# Best mean reward: 49.17 - Last mean reward per episode: 39.89
# Num timesteps: 135000
# Best mean reward: 49.17 - Last mean reward per episode: 40.40
# Num timesteps: 136000
# Best mean reward: 49.17 - Last mean reward per episode: 40.66
# Num timesteps: 137000
# Best mean reward: 49.17 - Last mean reward per episode: 40.79
# Num timesteps: 138000
# Best mean reward: 49.17 - Last mean reward per episode: 40.99
# Num timesteps: 139000
# Best mean reward: 49.17 - Last mean reward per episode: 41.21
# Num timesteps: 140000
# Best mean reward: 49.17 - Last mean reward per episode: 41.13
# Num timesteps: 141000
# Best mean reward: 49.17 - Last mean reward per episode: 40.26
# Num timesteps: 142000
# Best mean reward: 49.17 - Last mean reward per episode: 40.51
# Num timesteps: 143000
# Best mean reward: 49.17 - Last mean reward per episode: 40.40
# Num timesteps: 144000
# Best mean reward: 49.17 - Last mean reward per episode: 40.57
# Num timesteps: 145000
# Best mean reward: 49.17 - Last mean reward per episode: 41.36
# Num timesteps: 146000
# Best mean reward: 49.17 - Last mean reward per episode: 41.90
# Num timesteps: 147000
# Best mean reward: 49.17 - Last mean reward per episode: 42.30
# Num timesteps: 148000
# Best mean reward: 49.17 - Last mean reward per episode: 42.68
# Num timesteps: 149000
# Best mean reward: 49.17 - Last mean reward per episode: 42.92
# Num timesteps: 150000
# Best mean reward: 49.17 - Last mean reward per episode: 42.04
# Num timesteps: 151000
# Best mean reward: 49.17 - Last mean reward per episode: 42.17
# Num timesteps: 152000
# Best mean reward: 49.17 - Last mean reward per episode: 41.94
# Num timesteps: 153000
# Best mean reward: 49.17 - Last mean reward per episode: 41.03
# Num timesteps: 154000
# Best mean reward: 49.17 - Last mean reward per episode: 41.37
# Num timesteps: 155000
# Best mean reward: 49.17 - Last mean reward per episode: 41.33
# Num timesteps: 156000
# Best mean reward: 49.17 - Last mean reward per episode: 41.33
# Num timesteps: 157000
# Best mean reward: 49.17 - Last mean reward per episode: 41.31
# Num timesteps: 158000
# Best mean reward: 49.17 - Last mean reward per episode: 42.20
# Num timesteps: 159000
# Best mean reward: 49.17 - Last mean reward per episode: 41.47
# Num timesteps: 160000
# Best mean reward: 49.17 - Last mean reward per episode: 41.46
# Num timesteps: 161000
# Best mean reward: 49.17 - Last mean reward per episode: 40.87
# Num timesteps: 162000
# Best mean reward: 49.17 - Last mean reward per episode: 40.18
# Num timesteps: 163000
# Best mean reward: 49.17 - Last mean reward per episode: 39.75
# Num timesteps: 164000
# Best mean reward: 49.17 - Last mean reward per episode: 39.37
# Num timesteps: 165000
# Best mean reward: 49.17 - Last mean reward per episode: 39.18
# Num timesteps: 166000
# Best mean reward: 49.17 - Last mean reward per episode: 39.19
# Num timesteps: 167000
# Best mean reward: 49.17 - Last mean reward per episode: 39.46
# Num timesteps: 168000
# Best mean reward: 49.17 - Last mean reward per episode: 39.16
# Num timesteps: 169000
# Best mean reward: 49.17 - Last mean reward per episode: 38.83
# Num timesteps: 170000
# Best mean reward: 49.17 - Last mean reward per episode: 38.92
# Num timesteps: 171000
# Best mean reward: 49.17 - Last mean reward per episode: 38.51
# Num timesteps: 172000
# Best mean reward: 49.17 - Last mean reward per episode: 38.49
# Num timesteps: 173000
# Best mean reward: 49.17 - Last mean reward per episode: 38.81
# Num timesteps: 174000
# Best mean reward: 49.17 - Last mean reward per episode: 38.96
# Num timesteps: 175000
# Best mean reward: 49.17 - Last mean reward per episode: 39.18
# Num timesteps: 176000
# Best mean reward: 49.17 - Last mean reward per episode: 39.36
# Num timesteps: 177000
# Best mean reward: 49.17 - Last mean reward per episode: 39.02
# Num timesteps: 178000
# Best mean reward: 49.17 - Last mean reward per episode: 38.72
# Num timesteps: 179000
# Best mean reward: 49.17 - Last mean reward per episode: 39.14
# Num timesteps: 180000
# Best mean reward: 49.17 - Last mean reward per episode: 38.14
# Num timesteps: 181000
# Best mean reward: 49.17 - Last mean reward per episode: 37.99
# Num timesteps: 182000
# Best mean reward: 49.17 - Last mean reward per episode: 37.65
# Num timesteps: 183000
# Best mean reward: 49.17 - Last mean reward per episode: 37.43
# Num timesteps: 184000
# Best mean reward: 49.17 - Last mean reward per episode: 36.54
# Num timesteps: 185000
# Best mean reward: 49.17 - Last mean reward per episode: 36.92
# Num timesteps: 186000
# Best mean reward: 49.17 - Last mean reward per episode: 37.07
# Num timesteps: 187000
# Best mean reward: 49.17 - Last mean reward per episode: 37.03
# Num timesteps: 188000
# Best mean reward: 49.17 - Last mean reward per episode: 36.87
# Num timesteps: 189000
# Best mean reward: 49.17 - Last mean reward per episode: 37.37
# Num timesteps: 190000
# Best mean reward: 49.17 - Last mean reward per episode: 37.91
# Num timesteps: 191000
# Best mean reward: 49.17 - Last mean reward per episode: 37.88
# Num timesteps: 192000
# Best mean reward: 49.17 - Last mean reward per episode: 38.34
# Num timesteps: 193000
# Best mean reward: 49.17 - Last mean reward per episode: 38.82
# Num timesteps: 194000
# Best mean reward: 49.17 - Last mean reward per episode: 38.48
# Num timesteps: 195000
# Best mean reward: 49.17 - Last mean reward per episode: 38.21
# Num timesteps: 196000
# Best mean reward: 49.17 - Last mean reward per episode: 37.58
# Num timesteps: 197000
# Best mean reward: 49.17 - Last mean reward per episode: 37.11
# Num timesteps: 198000
# Best mean reward: 49.17 - Last mean reward per episode: 36.68
# Num timesteps: 199000
# Best mean reward: 49.17 - Last mean reward per episode: 36.44
# Num timesteps: 200000
# Best mean reward: 49.17 - Last mean reward per episode: 36.40
# Num timesteps: 201000
# Best mean reward: 49.17 - Last mean reward per episode: 36.53
# Num timesteps: 202000
# Best mean reward: 49.17 - Last mean reward per episode: 36.73
# Num timesteps: 203000
# Best mean reward: 49.17 - Last mean reward per episode: 36.57
# Num timesteps: 204000
# Best mean reward: 49.17 - Last mean reward per episode: 36.31
# Num timesteps: 205000
# Best mean reward: 49.17 - Last mean reward per episode: 36.02
# Num timesteps: 206000
# Best mean reward: 49.17 - Last mean reward per episode: 36.68
# Num timesteps: 207000
# Best mean reward: 49.17 - Last mean reward per episode: 36.54
# Num timesteps: 208000
# Best mean reward: 49.17 - Last mean reward per episode: 36.09
# Num timesteps: 209000
# Best mean reward: 49.17 - Last mean reward per episode: 35.94
# Num timesteps: 210000
# Best mean reward: 49.17 - Last mean reward per episode: 35.36
# Num timesteps: 211000
# Best mean reward: 49.17 - Last mean reward per episode: 34.15
# Num timesteps: 212000
# Best mean reward: 49.17 - Last mean reward per episode: 33.49
# Num timesteps: 213000
# Best mean reward: 49.17 - Last mean reward per episode: 33.28
# Num timesteps: 214000
# Best mean reward: 49.17 - Last mean reward per episode: 33.11
# Num timesteps: 215000
# Best mean reward: 49.17 - Last mean reward per episode: 32.81
# Num timesteps: 216000
# Best mean reward: 49.17 - Last mean reward per episode: 32.77
# Num timesteps: 217000
# Best mean reward: 49.17 - Last mean reward per episode: 32.47
# Num timesteps: 218000
# Best mean reward: 49.17 - Last mean reward per episode: 32.43
# Num timesteps: 219000
# Best mean reward: 49.17 - Last mean reward per episode: 32.69
# Num timesteps: 220000
# Best mean reward: 49.17 - Last mean reward per episode: 32.87
# Num timesteps: 221000
# Best mean reward: 49.17 - Last mean reward per episode: 32.83
# Num timesteps: 222000
# Best mean reward: 49.17 - Last mean reward per episode: 32.48
# Num timesteps: 223000
# Best mean reward: 49.17 - Last mean reward per episode: 32.30
# Num timesteps: 224000
# Best mean reward: 49.17 - Last mean reward per episode: 31.74
# Num timesteps: 225000
# Best mean reward: 49.17 - Last mean reward per episode: 31.63
# Num timesteps: 226000
# Best mean reward: 49.17 - Last mean reward per episode: 31.35
# Num timesteps: 227000
# Best mean reward: 49.17 - Last mean reward per episode: 31.30
# Num timesteps: 228000
# Best mean reward: 49.17 - Last mean reward per episode: 31.46
# Num timesteps: 229000
# Best mean reward: 49.17 - Last mean reward per episode: 31.28
# Num timesteps: 230000
# Best mean reward: 49.17 - Last mean reward per episode: 31.27
# Num timesteps: 231000
# Best mean reward: 49.17 - Last mean reward per episode: 31.54
# Num timesteps: 232000
# Best mean reward: 49.17 - Last mean reward per episode: 32.26
# Num timesteps: 233000
# Best mean reward: 49.17 - Last mean reward per episode: 32.09
# Num timesteps: 234000
# Best mean reward: 49.17 - Last mean reward per episode: 32.71
# Num timesteps: 235000
# Best mean reward: 49.17 - Last mean reward per episode: 33.03
# Num timesteps: 236000
# Best mean reward: 49.17 - Last mean reward per episode: 32.83
# Num timesteps: 237000
# Best mean reward: 49.17 - Last mean reward per episode: 32.53
# Num timesteps: 238000
# Best mean reward: 49.17 - Last mean reward per episode: 32.68
# Num timesteps: 239000
# Best mean reward: 49.17 - Last mean reward per episode: 32.70
# Num timesteps: 240000
# Best mean reward: 49.17 - Last mean reward per episode: 32.26
# Num timesteps: 241000
# Best mean reward: 49.17 - Last mean reward per episode: 32.23
# Num timesteps: 242000
# Best mean reward: 49.17 - Last mean reward per episode: 32.49
# Num timesteps: 243000
# Best mean reward: 49.17 - Last mean reward per episode: 32.95
# Num timesteps: 244000
# Best mean reward: 49.17 - Last mean reward per episode: 33.15
# Num timesteps: 245000
# Best mean reward: 49.17 - Last mean reward per episode: 33.10
# Num timesteps: 246000
# Best mean reward: 49.17 - Last mean reward per episode: 33.30
# Num timesteps: 247000
# Best mean reward: 49.17 - Last mean reward per episode: 33.42
# Num timesteps: 248000
# Best mean reward: 49.17 - Last mean reward per episode: 33.08
# Num timesteps: 249000
# Best mean reward: 49.17 - Last mean reward per episode: 32.90
# Num timesteps: 250000
# Best mean reward: 49.17 - Last mean reward per episode: 32.80
# Num timesteps: 251000
# Best mean reward: 49.17 - Last mean reward per episode: 32.68
# Num timesteps: 252000
# Best mean reward: 49.17 - Last mean reward per episode: 32.53
# Num timesteps: 253000
# Best mean reward: 49.17 - Last mean reward per episode: 32.64
# Num timesteps: 254000
# Best mean reward: 49.17 - Last mean reward per episode: 32.26
# Num timesteps: 255000
# Best mean reward: 49.17 - Last mean reward per episode: 32.34
# Num timesteps: 256000
# Best mean reward: 49.17 - Last mean reward per episode: 32.04
# Num timesteps: 257000
# Best mean reward: 49.17 - Last mean reward per episode: 32.19
# Num timesteps: 258000
# Best mean reward: 49.17 - Last mean reward per episode: 32.21
# Num timesteps: 259000
# Best mean reward: 49.17 - Last mean reward per episode: 32.78
# Num timesteps: 260000
# Best mean reward: 49.17 - Last mean reward per episode: 33.33
# Num timesteps: 261000
# Best mean reward: 49.17 - Last mean reward per episode: 33.70
# Num timesteps: 262000
# Best mean reward: 49.17 - Last mean reward per episode: 33.59
# Num timesteps: 263000
# Best mean reward: 49.17 - Last mean reward per episode: 33.69
# Num timesteps: 264000
# Best mean reward: 49.17 - Last mean reward per episode: 33.22
# Num timesteps: 265000
# Best mean reward: 49.17 - Last mean reward per episode: 32.82
# Num timesteps: 266000
# Best mean reward: 49.17 - Last mean reward per episode: 32.99
# Num timesteps: 267000
# Best mean reward: 49.17 - Last mean reward per episode: 32.89
# Num timesteps: 268000
# Best mean reward: 49.17 - Last mean reward per episode: 32.47
# Num timesteps: 269000
# Best mean reward: 49.17 - Last mean reward per episode: 32.90
# Num timesteps: 270000
# Best mean reward: 49.17 - Last mean reward per episode: 32.98
# Num timesteps: 271000
# Best mean reward: 49.17 - Last mean reward per episode: 33.17
# Num timesteps: 272000
# Best mean reward: 49.17 - Last mean reward per episode: 32.90
# Num timesteps: 273000
# Best mean reward: 49.17 - Last mean reward per episode: 32.76
# Num timesteps: 274000
# Best mean reward: 49.17 - Last mean reward per episode: 32.34
# Num timesteps: 275000
# Best mean reward: 49.17 - Last mean reward per episode: 32.46
# Num timesteps: 276000
# Best mean reward: 49.17 - Last mean reward per episode: 32.02
# Num timesteps: 277000
# Best mean reward: 49.17 - Last mean reward per episode: 32.35
# Num timesteps: 278000
# Best mean reward: 49.17 - Last mean reward per episode: 32.72
# Num timesteps: 279000
# Best mean reward: 49.17 - Last mean reward per episode: 32.56
# Num timesteps: 280000
# Best mean reward: 49.17 - Last mean reward per episode: 31.58
# Num timesteps: 281000
# Best mean reward: 49.17 - Last mean reward per episode: 31.62
# Num timesteps: 282000
# Best mean reward: 49.17 - Last mean reward per episode: 31.18
# Num timesteps: 283000
# Best mean reward: 49.17 - Last mean reward per episode: 31.23
# Num timesteps: 284000
# Best mean reward: 49.17 - Last mean reward per episode: 31.29
# Num timesteps: 285000
# Best mean reward: 49.17 - Last mean reward per episode: 32.09
# Num timesteps: 286000
# Best mean reward: 49.17 - Last mean reward per episode: 32.16
# Num timesteps: 287000
# Best mean reward: 49.17 - Last mean reward per episode: 32.07
# Num timesteps: 288000
# Best mean reward: 49.17 - Last mean reward per episode: 31.80
# Num timesteps: 289000
# Best mean reward: 49.17 - Last mean reward per episode: 32.41
# Num timesteps: 290000
# Best mean reward: 49.17 - Last mean reward per episode: 32.44
# Num timesteps: 291000
# Best mean reward: 49.17 - Last mean reward per episode: 32.76
# Num timesteps: 292000
# Best mean reward: 49.17 - Last mean reward per episode: 33.02
# Num timesteps: 293000
# Best mean reward: 49.17 - Last mean reward per episode: 32.92
# Num timesteps: 294000
# Best mean reward: 49.17 - Last mean reward per episode: 32.59
# Num timesteps: 295000
# Best mean reward: 49.17 - Last mean reward per episode: 33.08
# Num timesteps: 296000
# Best mean reward: 49.17 - Last mean reward per episode: 33.14
# Num timesteps: 297000
# Best mean reward: 49.17 - Last mean reward per episode: 33.37
# Num timesteps: 298000
# Best mean reward: 49.17 - Last mean reward per episode: 33.60
# Num timesteps: 299000
# Best mean reward: 49.17 - Last mean reward per episode: 33.68
# Num timesteps: 300000
# Best mean reward: 49.17 - Last mean reward per episode: 33.02
# Num timesteps: 301000
# Best mean reward: 49.17 - Last mean reward per episode: 32.57
# Num timesteps: 302000
# Best mean reward: 49.17 - Last mean reward per episode: 32.02
# Num timesteps: 303000
# Best mean reward: 49.17 - Last mean reward per episode: 31.94
# Num timesteps: 304000
# Best mean reward: 49.17 - Last mean reward per episode: 31.35
# Num timesteps: 305000
# Best mean reward: 49.17 - Last mean reward per episode: 31.28
# Num timesteps: 306000
# Best mean reward: 49.17 - Last mean reward per episode: 30.86
# Num timesteps: 307000
# Best mean reward: 49.17 - Last mean reward per episode: 30.96
# Num timesteps: 308000
# Best mean reward: 49.17 - Last mean reward per episode: 30.61
# Num timesteps: 309000
# Best mean reward: 49.17 - Last mean reward per episode: 30.37
# Num timesteps: 310000
# Best mean reward: 49.17 - Last mean reward per episode: 30.10
# Num timesteps: 311000
# Best mean reward: 49.17 - Last mean reward per episode: 29.65
# Num timesteps: 312000
# Best mean reward: 49.17 - Last mean reward per episode: 29.18
# Num timesteps: 313000
# Best mean reward: 49.17 - Last mean reward per episode: 29.26
# Num timesteps: 314000
# Best mean reward: 49.17 - Last mean reward per episode: 29.26
# Num timesteps: 315000
# Best mean reward: 49.17 - Last mean reward per episode: 29.05
# Num timesteps: 316000
# Best mean reward: 49.17 - Last mean reward per episode: 29.33
# Num timesteps: 317000
# Best mean reward: 49.17 - Last mean reward per episode: 29.70
# Num timesteps: 318000
# Best mean reward: 49.17 - Last mean reward per episode: 29.54
# Num timesteps: 319000
# Best mean reward: 49.17 - Last mean reward per episode: 29.69
# Num timesteps: 320000
# Best mean reward: 49.17 - Last mean reward per episode: 29.69
# Num timesteps: 321000
# Best mean reward: 49.17 - Last mean reward per episode: 29.57
# Num timesteps: 322000
# Best mean reward: 49.17 - Last mean reward per episode: 29.58
# Num timesteps: 323000
# Best mean reward: 49.17 - Last mean reward per episode: 29.33
# Num timesteps: 324000
# Best mean reward: 49.17 - Last mean reward per episode: 29.15
# Num timesteps: 325000
# Best mean reward: 49.17 - Last mean reward per episode: 29.50
# Num timesteps: 326000
# Best mean reward: 49.17 - Last mean reward per episode: 29.74
# Num timesteps: 327000
# Best mean reward: 49.17 - Last mean reward per episode: 30.01
# Num timesteps: 328000
# Best mean reward: 49.17 - Last mean reward per episode: 30.30
# Num timesteps: 329000
# Best mean reward: 49.17 - Last mean reward per episode: 30.41
# Num timesteps: 330000
# Best mean reward: 49.17 - Last mean reward per episode: 29.89
# Num timesteps: 331000
# Best mean reward: 49.17 - Last mean reward per episode: 29.55
# Num timesteps: 332000
# Best mean reward: 49.17 - Last mean reward per episode: 29.13
# Num timesteps: 333000
# Best mean reward: 49.17 - Last mean reward per episode: 28.85
# Num timesteps: 334000
# Best mean reward: 49.17 - Last mean reward per episode: 28.41
# Num timesteps: 335000
# Best mean reward: 49.17 - Last mean reward per episode: 28.45
# Num timesteps: 336000
# Best mean reward: 49.17 - Last mean reward per episode: 28.55
# Num timesteps: 337000
# Best mean reward: 49.17 - Last mean reward per episode: 28.58
# Num timesteps: 338000
# Best mean reward: 49.17 - Last mean reward per episode: 28.84
# Num timesteps: 339000
# Best mean reward: 49.17 - Last mean reward per episode: 29.16
# Num timesteps: 340000
# Best mean reward: 49.17 - Last mean reward per episode: 29.14
# Num timesteps: 341000
# Best mean reward: 49.17 - Last mean reward per episode: 28.83
# Num timesteps: 342000
# Best mean reward: 49.17 - Last mean reward per episode: 28.28
# Num timesteps: 343000
# Best mean reward: 49.17 - Last mean reward per episode: 28.01
# Num timesteps: 344000
# Best mean reward: 49.17 - Last mean reward per episode: 27.69
# Num timesteps: 345000
# Best mean reward: 49.17 - Last mean reward per episode: 27.44
# Num timesteps: 346000
# Best mean reward: 49.17 - Last mean reward per episode: 27.81
# Num timesteps: 347000
# Best mean reward: 49.17 - Last mean reward per episode: 28.55
# Num timesteps: 348000
# Best mean reward: 49.17 - Last mean reward per episode: 28.29
# Num timesteps: 349000
# Best mean reward: 49.17 - Last mean reward per episode: 28.83
# Num timesteps: 350000
# Best mean reward: 49.17 - Last mean reward per episode: 29.51
# Num timesteps: 351000
# Best mean reward: 49.17 - Last mean reward per episode: 29.08
# Num timesteps: 352000
# Best mean reward: 49.17 - Last mean reward per episode: 28.62
# Num timesteps: 353000
# Best mean reward: 49.17 - Last mean reward per episode: 28.65
# Num timesteps: 354000
# Best mean reward: 49.17 - Last mean reward per episode: 28.22
# Num timesteps: 355000
# Best mean reward: 49.17 - Last mean reward per episode: 27.48
# Num timesteps: 356000
# Best mean reward: 49.17 - Last mean reward per episode: 27.47
# Num timesteps: 357000
# Best mean reward: 49.17 - Last mean reward per episode: 27.32
# Num timesteps: 358000
# Best mean reward: 49.17 - Last mean reward per episode: 27.20
# Num timesteps: 359000
# Best mean reward: 49.17 - Last mean reward per episode: 27.04
# Num timesteps: 360000
# Best mean reward: 49.17 - Last mean reward per episode: 27.21
# Num timesteps: 361000
# Best mean reward: 49.17 - Last mean reward per episode: 27.06
# Num timesteps: 362000
# Best mean reward: 49.17 - Last mean reward per episode: 27.03
# Num timesteps: 363000
# Best mean reward: 49.17 - Last mean reward per episode: 26.95
# Num timesteps: 364000
# Best mean reward: 49.17 - Last mean reward per episode: 26.84
# Num timesteps: 365000
# Best mean reward: 49.17 - Last mean reward per episode: 26.86
# Num timesteps: 366000
# Best mean reward: 49.17 - Last mean reward per episode: 27.01
# Num timesteps: 367000
# Best mean reward: 49.17 - Last mean reward per episode: 27.16
# Num timesteps: 368000
# Best mean reward: 49.17 - Last mean reward per episode: 27.25
# Num timesteps: 369000
# Best mean reward: 49.17 - Last mean reward per episode: 27.55
# Num timesteps: 370000
# Best mean reward: 49.17 - Last mean reward per episode: 27.67
# Num timesteps: 371000
# Best mean reward: 49.17 - Last mean reward per episode: 28.01
# Num timesteps: 372000
# Best mean reward: 49.17 - Last mean reward per episode: 28.14
# Num timesteps: 373000
# Best mean reward: 49.17 - Last mean reward per episode: 28.25
# Num timesteps: 374000
# Best mean reward: 49.17 - Last mean reward per episode: 27.94
# Num timesteps: 375000
# Best mean reward: 49.17 - Last mean reward per episode: 27.68
# Num timesteps: 376000
# Best mean reward: 49.17 - Last mean reward per episode: 27.45
# Num timesteps: 377000
# Best mean reward: 49.17 - Last mean reward per episode: 27.16
# Num timesteps: 378000
# Best mean reward: 49.17 - Last mean reward per episode: 26.89
# Num timesteps: 379000
# Best mean reward: 49.17 - Last mean reward per episode: 27.11
# Num timesteps: 380000
# Best mean reward: 49.17 - Last mean reward per episode: 27.22
# Num timesteps: 381000
# Best mean reward: 49.17 - Last mean reward per episode: 26.97
# Num timesteps: 382000
# Best mean reward: 49.17 - Last mean reward per episode: 27.01
# Num timesteps: 383000
# Best mean reward: 49.17 - Last mean reward per episode: 27.10
# Num timesteps: 384000
# Best mean reward: 49.17 - Last mean reward per episode: 27.19
# Num timesteps: 385000
# Best mean reward: 49.17 - Last mean reward per episode: 27.21
# Num timesteps: 386000
# Best mean reward: 49.17 - Last mean reward per episode: 27.50
# Num timesteps: 387000
# Best mean reward: 49.17 - Last mean reward per episode: 27.61
# Num timesteps: 388000
# Best mean reward: 49.17 - Last mean reward per episode: 27.94
# Num timesteps: 389000
# Best mean reward: 49.17 - Last mean reward per episode: 27.76
# Num timesteps: 390000
# Best mean reward: 49.17 - Last mean reward per episode: 27.74
# Num timesteps: 391000
# Best mean reward: 49.17 - Last mean reward per episode: 27.95
# Num timesteps: 392000
# Best mean reward: 49.17 - Last mean reward per episode: 27.89
# Num timesteps: 393000
# Best mean reward: 49.17 - Last mean reward per episode: 27.86
# Num timesteps: 394000
# Best mean reward: 49.17 - Last mean reward per episode: 27.84
# Num timesteps: 395000
# Best mean reward: 49.17 - Last mean reward per episode: 27.69
# Num timesteps: 396000
# Best mean reward: 49.17 - Last mean reward per episode: 27.45
# Num timesteps: 397000
# Best mean reward: 49.17 - Last mean reward per episode: 27.57
# Num timesteps: 398000
# Best mean reward: 49.17 - Last mean reward per episode: 27.61
# Num timesteps: 399000
# Best mean reward: 49.17 - Last mean reward per episode: 27.69
# Num timesteps: 400000
# Best mean reward: 49.17 - Last mean reward per episode: 27.69
# Num timesteps: 401000
# Best mean reward: 49.17 - Last mean reward per episode: 27.46
# Num timesteps: 402000
# Best mean reward: 49.17 - Last mean reward per episode: 27.12
# Num timesteps: 403000
# Best mean reward: 49.17 - Last mean reward per episode: 26.88
# Num timesteps: 404000
# Best mean reward: 49.17 - Last mean reward per episode: 26.42
# Num timesteps: 405000
# Best mean reward: 49.17 - Last mean reward per episode: 25.93
# Num timesteps: 406000
# Best mean reward: 49.17 - Last mean reward per episode: 25.84
# Num timesteps: 407000
# Best mean reward: 49.17 - Last mean reward per episode: 25.58
# Num timesteps: 408000
# Best mean reward: 49.17 - Last mean reward per episode: 25.34
# Num timesteps: 409000
# Best mean reward: 49.17 - Last mean reward per episode: 25.31
# Num timesteps: 410000
# Best mean reward: 49.17 - Last mean reward per episode: 25.32
# Num timesteps: 411000
# Best mean reward: 49.17 - Last mean reward per episode: 24.98
# Num timesteps: 412000
# Best mean reward: 49.17 - Last mean reward per episode: 25.04
# Num timesteps: 413000
# Best mean reward: 49.17 - Last mean reward per episode: 24.83
# Num timesteps: 414000
# Best mean reward: 49.17 - Last mean reward per episode: 24.82
# Num timesteps: 415000
# Best mean reward: 49.17 - Last mean reward per episode: 25.10
# Num timesteps: 416000
# Best mean reward: 49.17 - Last mean reward per episode: 25.21
# Num timesteps: 417000
# Best mean reward: 49.17 - Last mean reward per episode: 25.09
# Num timesteps: 418000
# Best mean reward: 49.17 - Last mean reward per episode: 24.94
# Num timesteps: 419000
# Best mean reward: 49.17 - Last mean reward per episode: 24.62
# Num timesteps: 420000
# Best mean reward: 49.17 - Last mean reward per episode: 24.25
# Num timesteps: 421000
# Best mean reward: 49.17 - Last mean reward per episode: 23.97
# Num timesteps: 422000
# Best mean reward: 49.17 - Last mean reward per episode: 23.78
# Num timesteps: 423000
# Best mean reward: 49.17 - Last mean reward per episode: 23.91
# Num timesteps: 424000
# Best mean reward: 49.17 - Last mean reward per episode: 23.93
# Num timesteps: 425000
# Best mean reward: 49.17 - Last mean reward per episode: 23.82
# Num timesteps: 426000
# Best mean reward: 49.17 - Last mean reward per episode: 23.80
# Num timesteps: 427000
# Best mean reward: 49.17 - Last mean reward per episode: 23.72
# Num timesteps: 428000
# Best mean reward: 49.17 - Last mean reward per episode: 23.49
# Num timesteps: 429000
# Best mean reward: 49.17 - Last mean reward per episode: 23.48
# Num timesteps: 430000
# Best mean reward: 49.17 - Last mean reward per episode: 23.51
# Num timesteps: 431000
# Best mean reward: 49.17 - Last mean reward per episode: 23.60
# Num timesteps: 432000
# Best mean reward: 49.17 - Last mean reward per episode: 23.33
# Num timesteps: 433000
# Best mean reward: 49.17 - Last mean reward per episode: 23.44
# Num timesteps: 434000
# Best mean reward: 49.17 - Last mean reward per episode: 23.33
# Num timesteps: 435000
# Best mean reward: 49.17 - Last mean reward per episode: 23.06
# Num timesteps: 436000
# Best mean reward: 49.17 - Last mean reward per episode: 22.96
# Num timesteps: 437000
# Best mean reward: 49.17 - Last mean reward per episode: 23.19
# Num timesteps: 438000
# Best mean reward: 49.17 - Last mean reward per episode: 22.82
# Num timesteps: 439000
# Best mean reward: 49.17 - Last mean reward per episode: 22.61
# Num timesteps: 440000
# Best mean reward: 49.17 - Last mean reward per episode: 22.50
# Num timesteps: 441000
# Best mean reward: 49.17 - Last mean reward per episode: 22.44
# Num timesteps: 442000
# Best mean reward: 49.17 - Last mean reward per episode: 22.38
# Num timesteps: 443000
# Best mean reward: 49.17 - Last mean reward per episode: 22.38
# Num timesteps: 444000
# Best mean reward: 49.17 - Last mean reward per episode: 22.20
# Num timesteps: 445000
# Best mean reward: 49.17 - Last mean reward per episode: 22.14
# Num timesteps: 446000
# Best mean reward: 49.17 - Last mean reward per episode: 21.75
# Num timesteps: 447000
# Best mean reward: 49.17 - Last mean reward per episode: 21.36
# Num timesteps: 448000
# Best mean reward: 49.17 - Last mean reward per episode: 21.01
# Num timesteps: 449000
# Best mean reward: 49.17 - Last mean reward per episode: 21.01
# Num timesteps: 450000
# Best mean reward: 49.17 - Last mean reward per episode: 20.89
# Num timesteps: 451000
# Best mean reward: 49.17 - Last mean reward per episode: 20.68
# Num timesteps: 452000
# Best mean reward: 49.17 - Last mean reward per episode: 20.44
# Num timesteps: 453000
# Best mean reward: 49.17 - Last mean reward per episode: 20.39
# Num timesteps: 454000
# Best mean reward: 49.17 - Last mean reward per episode: 20.20
# Num timesteps: 455000
# Best mean reward: 49.17 - Last mean reward per episode: 20.01
# Num timesteps: 456000
# Best mean reward: 49.17 - Last mean reward per episode: 20.14
# Num timesteps: 457000
# Best mean reward: 49.17 - Last mean reward per episode: 20.20
# Num timesteps: 458000
# Best mean reward: 49.17 - Last mean reward per episode: 20.23
# Num timesteps: 459000
# Best mean reward: 49.17 - Last mean reward per episode: 20.25
# Num timesteps: 460000
# Best mean reward: 49.17 - Last mean reward per episode: 20.35
# Num timesteps: 461000
# Best mean reward: 49.17 - Last mean reward per episode: 20.10
# Num timesteps: 462000
# Best mean reward: 49.17 - Last mean reward per episode: 19.97
# Num timesteps: 463000
# Best mean reward: 49.17 - Last mean reward per episode: 19.89
# Num timesteps: 464000
# Best mean reward: 49.17 - Last mean reward per episode: 19.78
# Num timesteps: 465000
# Best mean reward: 49.17 - Last mean reward per episode: 19.89
# Num timesteps: 466000
# Best mean reward: 49.17 - Last mean reward per episode: 20.17
# Num timesteps: 467000
# Best mean reward: 49.17 - Last mean reward per episode: 20.24
# Num timesteps: 468000
# Best mean reward: 49.17 - Last mean reward per episode: 20.32
# Num timesteps: 469000
# Best mean reward: 49.17 - Last mean reward per episode: 20.57
# Num timesteps: 470000
# Best mean reward: 49.17 - Last mean reward per episode: 20.46
# Num timesteps: 471000
# Best mean reward: 49.17 - Last mean reward per episode: 20.54
# Num timesteps: 472000
# Best mean reward: 49.17 - Last mean reward per episode: 20.58
# Num timesteps: 473000
# Best mean reward: 49.17 - Last mean reward per episode: 20.62
# Num timesteps: 474000
# Best mean reward: 49.17 - Last mean reward per episode: 20.50
# Num timesteps: 475000
# Best mean reward: 49.17 - Last mean reward per episode: 20.23
# Num timesteps: 476000
# Best mean reward: 49.17 - Last mean reward per episode: 19.97
# Num timesteps: 477000
# Best mean reward: 49.17 - Last mean reward per episode: 19.89
# Num timesteps: 478000
# Best mean reward: 49.17 - Last mean reward per episode: 19.85
# Num timesteps: 479000
# Best mean reward: 49.17 - Last mean reward per episode: 19.78
# Num timesteps: 480000
# Best mean reward: 49.17 - Last mean reward per episode: 19.93
# Num timesteps: 481000
# Best mean reward: 49.17 - Last mean reward per episode: 19.96
# Num timesteps: 482000
# Best mean reward: 49.17 - Last mean reward per episode: 19.96
# Num timesteps: 483000
# Best mean reward: 49.17 - Last mean reward per episode: 19.97
# Num timesteps: 484000
# Best mean reward: 49.17 - Last mean reward per episode: 19.91
# Num timesteps: 485000
# Best mean reward: 49.17 - Last mean reward per episode: 19.89
# Num timesteps: 486000
# Best mean reward: 49.17 - Last mean reward per episode: 19.95
# Num timesteps: 487000
# Best mean reward: 49.17 - Last mean reward per episode: 19.96
# Num timesteps: 488000
# Best mean reward: 49.17 - Last mean reward per episode: 19.70
# Num timesteps: 489000
# Best mean reward: 49.17 - Last mean reward per episode: 19.81
# Num timesteps: 490000
# Best mean reward: 49.17 - Last mean reward per episode: 19.81
# Num timesteps: 491000
# Best mean reward: 49.17 - Last mean reward per episode: 19.74
# Num timesteps: 492000
# Best mean reward: 49.17 - Last mean reward per episode: 19.63
# Num timesteps: 493000
# Best mean reward: 49.17 - Last mean reward per episode: 19.74
# Num timesteps: 494000
# Best mean reward: 49.17 - Last mean reward per episode: 19.66
# Num timesteps: 495000
# Best mean reward: 49.17 - Last mean reward per episode: 19.70
# Num timesteps: 496000
# Best mean reward: 49.17 - Last mean reward per episode: 19.73
# Num timesteps: 497000
# Best mean reward: 49.17 - Last mean reward per episode: 19.75
# Num timesteps: 498000
# Best mean reward: 49.17 - Last mean reward per episode: 19.71
# Num timesteps: 499000
# Best mean reward: 49.17 - Last mean reward per episode: 19.61
# Num timesteps: 500000
# Best mean reward: 49.17 - Last mean reward per episode: 19.58
# Num timesteps: 501000
# Best mean reward: 49.17 - Last mean reward per episode: 19.52
# Num timesteps: 502000
# Best mean reward: 49.17 - Last mean reward per episode: 19.49
# Num timesteps: 503000
# Best mean reward: 49.17 - Last mean reward per episode: 19.69
# Num timesteps: 504000
# Best mean reward: 49.17 - Last mean reward per episode: 19.70
# Num timesteps: 505000
# Best mean reward: 49.17 - Last mean reward per episode: 19.62
# Num timesteps: 506000
# Best mean reward: 49.17 - Last mean reward per episode: 19.68
# Num timesteps: 507000
# Best mean reward: 49.17 - Last mean reward per episode: 19.63
# Num timesteps: 508000
# Best mean reward: 49.17 - Last mean reward per episode: 19.42
# Num timesteps: 509000
# Best mean reward: 49.17 - Last mean reward per episode: 19.42
# Num timesteps: 510000
# Best mean reward: 49.17 - Last mean reward per episode: 19.41
# Num timesteps: 511000
# Best mean reward: 49.17 - Last mean reward per episode: 19.32
# Num timesteps: 512000
# Best mean reward: 49.17 - Last mean reward per episode: 19.39
# Num timesteps: 513000
# Best mean reward: 49.17 - Last mean reward per episode: 19.46
# Num timesteps: 514000
# Best mean reward: 49.17 - Last mean reward per episode: 19.43
# Num timesteps: 515000
# Best mean reward: 49.17 - Last mean reward per episode: 19.52
# Num timesteps: 516000
# Best mean reward: 49.17 - Last mean reward per episode: 19.60
# Num timesteps: 517000
# Best mean reward: 49.17 - Last mean reward per episode: 19.63
# Num timesteps: 518000
# Best mean reward: 49.17 - Last mean reward per episode: 19.51
# Num timesteps: 519000
# Best mean reward: 49.17 - Last mean reward per episode: 19.40
# Num timesteps: 520000
# Best mean reward: 49.17 - Last mean reward per episode: 19.31
# Num timesteps: 521000
# Best mean reward: 49.17 - Last mean reward per episode: 19.20
# Num timesteps: 522000
# Best mean reward: 49.17 - Last mean reward per episode: 19.09
# Num timesteps: 523000
# Best mean reward: 49.17 - Last mean reward per episode: 19.05
# Num timesteps: 524000
# Best mean reward: 49.17 - Last mean reward per episode: 19.17
# Num timesteps: 525000
# Best mean reward: 49.17 - Last mean reward per episode: 19.09
# Num timesteps: 526000
# Best mean reward: 49.17 - Last mean reward per episode: 19.02
# Num timesteps: 527000
# Best mean reward: 49.17 - Last mean reward per episode: 18.95
# Num timesteps: 528000
# Best mean reward: 49.17 - Last mean reward per episode: 19.02
# Num timesteps: 529000
# Best mean reward: 49.17 - Last mean reward per episode: 19.00
# Num timesteps: 530000
# Best mean reward: 49.17 - Last mean reward per episode: 19.02
# Num timesteps: 531000
# Best mean reward: 49.17 - Last mean reward per episode: 19.09
# Num timesteps: 532000
# Best mean reward: 49.17 - Last mean reward per episode: 19.25
# Num timesteps: 533000
# Best mean reward: 49.17 - Last mean reward per episode: 19.24
# Num timesteps: 534000
# Best mean reward: 49.17 - Last mean reward per episode: 19.15
# Num timesteps: 535000
# Best mean reward: 49.17 - Last mean reward per episode: 19.19
# Num timesteps: 536000
# Best mean reward: 49.17 - Last mean reward per episode: 19.17
# Num timesteps: 537000
# Best mean reward: 49.17 - Last mean reward per episode: 19.11
# Num timesteps: 538000
# Best mean reward: 49.17 - Last mean reward per episode: 19.08
# Num timesteps: 539000
# Best mean reward: 49.17 - Last mean reward per episode: 19.27
# Num timesteps: 540000
# Best mean reward: 49.17 - Last mean reward per episode: 19.22
# Num timesteps: 541000
# Best mean reward: 49.17 - Last mean reward per episode: 19.28
# Num timesteps: 542000
# Best mean reward: 49.17 - Last mean reward per episode: 19.28
# Num timesteps: 543000
# Best mean reward: 49.17 - Last mean reward per episode: 19.31
# Num timesteps: 544000
# Best mean reward: 49.17 - Last mean reward per episode: 19.10
# Num timesteps: 545000
# Best mean reward: 49.17 - Last mean reward per episode: 19.16
# Num timesteps: 546000
# Best mean reward: 49.17 - Last mean reward per episode: 19.14
# Num timesteps: 547000
# Best mean reward: 49.17 - Last mean reward per episode: 19.16
# Num timesteps: 548000
# Best mean reward: 49.17 - Last mean reward per episode: 19.19
# Num timesteps: 549000
# Best mean reward: 49.17 - Last mean reward per episode: 19.30
# Num timesteps: 550000
# Best mean reward: 49.17 - Last mean reward per episode: 19.21
# Num timesteps: 551000
# Best mean reward: 49.17 - Last mean reward per episode: 19.16
# Num timesteps: 552000
# Best mean reward: 49.17 - Last mean reward per episode: 19.22
# Num timesteps: 553000
# Best mean reward: 49.17 - Last mean reward per episode: 19.28
# Num timesteps: 554000
# Best mean reward: 49.17 - Last mean reward per episode: 19.26
# Num timesteps: 555000
# Best mean reward: 49.17 - Last mean reward per episode: 19.34
# Num timesteps: 556000
# Best mean reward: 49.17 - Last mean reward per episode: 19.32
# Num timesteps: 557000
# Best mean reward: 49.17 - Last mean reward per episode: 19.25
# Num timesteps: 558000
# Best mean reward: 49.17 - Last mean reward per episode: 19.21
# ...
# Num timesteps: 812000
# Best mean reward: 49.17 - Last mean reward per episode: 18.60
# Num timesteps: 813000
# Best mean reward: 49.17 - Last mean reward per episode: 18.58
# Num timesteps: 814000
# Best mean reward: 49.17 - Last mean reward per episode: 18.68
# Num timesteps: 815000
# Best mean reward: 49.17 - Last mean reward per episode: 18.71
# Num timesteps: 816000
# Best mean reward: 49.17 - Last mean reward per episode: 18.70
# Num timesteps: 817000
# Best mean reward: 49.17 - Last mean reward per episode: 18.72
# Num timesteps: 818000
# Best mean reward: 49.17 - Last mean reward per episode: 18.72
# Num timesteps: 819000
# Best mean reward: 49.17 - Last mean reward per episode: 18.61
# Num timesteps: 820000
# Best mean reward: 49.17 - Last mean reward per episode: 18.60
# Num timesteps: 821000
# Best mean reward: 49.17 - Last mean reward per episode: 18.61
# Num timesteps: 822000
# Best mean reward: 49.17 - Last mean reward per episode: 18.60
# Num timesteps: 823000
# Best mean reward: 49.17 - Last mean reward per episode: 18.62
# Num timesteps: 824000
# Best mean reward: 49.17 - Last mean reward per episode: 18.67
# Num timesteps: 825000
# Best mean reward: 49.17 - Last mean reward per episode: 18.68
# Num timesteps: 826000
# Best mean reward: 49.17 - Last mean reward per episode: 18.64
# Num timesteps: 827000
# Best mean reward: 49.17 - Last mean reward per episode: 18.64
# Num timesteps: 828000
# Best mean reward: 49.17 - Last mean reward per episode: 18.66
# Num timesteps: 829000
# Best mean reward: 49.17 - Last mean reward per episode: 18.64
# Num timesteps: 830000
# Best mean reward: 49.17 - Last mean reward per episode: 18.63
# Num timesteps: 831000
# Best mean reward: 49.17 - Last mean reward per episode: 18.62
# Num timesteps: 832000
# Best mean reward: 49.17 - Last mean reward per episode: 18.61
# Num timesteps: 833000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 834000
# Best mean reward: 49.17 - Last mean reward per episode: 18.50
# Num timesteps: 835000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 836000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 837000
# Best mean reward: 49.17 - Last mean reward per episode: 18.44
# Num timesteps: 838000
# Best mean reward: 49.17 - Last mean reward per episode: 18.45
# Num timesteps: 839000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 840000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 841000
# Best mean reward: 49.17 - Last mean reward per episode: 18.49
# Num timesteps: 842000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 843000
# Best mean reward: 49.17 - Last mean reward per episode: 18.49
# Num timesteps: 844000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 845000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 846000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 847000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 848000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 849000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 850000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 851000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 852000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 853000
# Best mean reward: 49.17 - Last mean reward per episode: 18.42
# Num timesteps: 854000
# Best mean reward: 49.17 - Last mean reward per episode: 18.39
# Num timesteps: 855000
# Best mean reward: 49.17 - Last mean reward per episode: 18.38
# Num timesteps: 856000
# Best mean reward: 49.17 - Last mean reward per episode: 18.35
# Num timesteps: 857000
# Best mean reward: 49.17 - Last mean reward per episode: 18.33
# Num timesteps: 858000
# Best mean reward: 49.17 - Last mean reward per episode: 18.37
# Num timesteps: 859000
# Best mean reward: 49.17 - Last mean reward per episode: 18.40
# Num timesteps: 860000
# Best mean reward: 49.17 - Last mean reward per episode: 18.45
# Num timesteps: 861000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 862000
# Best mean reward: 49.17 - Last mean reward per episode: 18.50
# Num timesteps: 863000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 864000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 865000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 866000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 867000
# Best mean reward: 49.17 - Last mean reward per episode: 18.58
# Num timesteps: 868000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 869000
# Best mean reward: 49.17 - Last mean reward per episode: 18.55
# Num timesteps: 870000
# Best mean reward: 49.17 - Last mean reward per episode: 18.55
# Num timesteps: 871000
# Best mean reward: 49.17 - Last mean reward per episode: 18.56
# Num timesteps: 872000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 873000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 874000
# Best mean reward: 49.17 - Last mean reward per episode: 18.45
# Num timesteps: 875000
# Best mean reward: 49.17 - Last mean reward per episode: 18.42
# Num timesteps: 876000
# Best mean reward: 49.17 - Last mean reward per episode: 18.44
# Num timesteps: 877000
# Best mean reward: 49.17 - Last mean reward per episode: 18.40
# Num timesteps: 878000
# Best mean reward: 49.17 - Last mean reward per episode: 18.41
# Num timesteps: 879000
# Best mean reward: 49.17 - Last mean reward per episode: 18.46
# Num timesteps: 880000
# Best mean reward: 49.17 - Last mean reward per episode: 18.45
# Num timesteps: 881000
# Best mean reward: 49.17 - Last mean reward per episode: 18.44
# Num timesteps: 882000
# Best mean reward: 49.17 - Last mean reward per episode: 18.50
# Num timesteps: 883000
# Best mean reward: 49.17 - Last mean reward per episode: 18.49
# Num timesteps: 884000
# Best mean reward: 49.17 - Last mean reward per episode: 18.43
# Num timesteps: 885000
# Best mean reward: 49.17 - Last mean reward per episode: 18.45
# Num timesteps: 886000
# Best mean reward: 49.17 - Last mean reward per episode: 18.43
# Num timesteps: 887000
# Best mean reward: 49.17 - Last mean reward per episode: 18.40
# Num timesteps: 888000
# Best mean reward: 49.17 - Last mean reward per episode: 18.37
# Num timesteps: 889000
# Best mean reward: 49.17 - Last mean reward per episode: 18.43
# Num timesteps: 890000
# Best mean reward: 49.17 - Last mean reward per episode: 18.41
# Num timesteps: 891000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 892000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 893000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 894000
# Best mean reward: 49.17 - Last mean reward per episode: 18.55
# Num timesteps: 895000
# Best mean reward: 49.17 - Last mean reward per episode: 18.57
# Num timesteps: 896000
# Best mean reward: 49.17 - Last mean reward per episode: 18.55
# Num timesteps: 897000
# Best mean reward: 49.17 - Last mean reward per episode: 18.60
# Num timesteps: 898000
# Best mean reward: 49.17 - Last mean reward per episode: 18.60
# Num timesteps: 899000
# Best mean reward: 49.17 - Last mean reward per episode: 18.57
# Num timesteps: 900000
# Best mean reward: 49.17 - Last mean reward per episode: 18.61
# Num timesteps: 901000
# Best mean reward: 49.17 - Last mean reward per episode: 18.58
# Num timesteps: 902000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 903000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 904000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 905000
# Best mean reward: 49.17 - Last mean reward per episode: 18.43
# Num timesteps: 906000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 907000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 908000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 909000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 910000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 911000
# Best mean reward: 49.17 - Last mean reward per episode: 18.44
# Num timesteps: 912000
# Best mean reward: 49.17 - Last mean reward per episode: 18.42
# Num timesteps: 913000
# Best mean reward: 49.17 - Last mean reward per episode: 18.42
# Num timesteps: 914000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 915000
# Best mean reward: 49.17 - Last mean reward per episode: 18.63
# Num timesteps: 916000
# Best mean reward: 49.17 - Last mean reward per episode: 18.65
# Num timesteps: 917000
# Best mean reward: 49.17 - Last mean reward per episode: 18.68
# Num timesteps: 918000
# Best mean reward: 49.17 - Last mean reward per episode: 18.66
# Num timesteps: 919000
# Best mean reward: 49.17 - Last mean reward per episode: 18.71
# Num timesteps: 920000
# Best mean reward: 49.17 - Last mean reward per episode: 18.71
# Num timesteps: 921000
# Best mean reward: 49.17 - Last mean reward per episode: 18.76
# Num timesteps: 922000
# Best mean reward: 49.17 - Last mean reward per episode: 18.92
# Num timesteps: 923000
# Best mean reward: 49.17 - Last mean reward per episode: 18.96
# Num timesteps: 924000
# Best mean reward: 49.17 - Last mean reward per episode: 18.95
# Num timesteps: 925000
# Best mean reward: 49.17 - Last mean reward per episode: 18.89
# Num timesteps: 926000
# Best mean reward: 49.17 - Last mean reward per episode: 18.90
# Num timesteps: 927000
# Best mean reward: 49.17 - Last mean reward per episode: 18.82
# Num timesteps: 928000
# Best mean reward: 49.17 - Last mean reward per episode: 18.83
# Num timesteps: 929000
# Best mean reward: 49.17 - Last mean reward per episode: 18.89
# Num timesteps: 930000
# Best mean reward: 49.17 - Last mean reward per episode: 18.99
# Num timesteps: 931000
# Best mean reward: 49.17 - Last mean reward per episode: 19.03
# Num timesteps: 932000
# Best mean reward: 49.17 - Last mean reward per episode: 19.08
# Num timesteps: 933000
# Best mean reward: 49.17 - Last mean reward per episode: 19.13
# Num timesteps: 934000
# Best mean reward: 49.17 - Last mean reward per episode: 19.11
# Num timesteps: 935000
# Best mean reward: 49.17 - Last mean reward per episode: 19.11
# Num timesteps: 936000
# Best mean reward: 49.17 - Last mean reward per episode: 18.94
# Num timesteps: 937000
# Best mean reward: 49.17 - Last mean reward per episode: 18.85
# Num timesteps: 938000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 939000
# Best mean reward: 49.17 - Last mean reward per episode: 18.92
# Num timesteps: 940000
# Best mean reward: 49.17 - Last mean reward per episode: 18.82
# Num timesteps: 941000
# Best mean reward: 49.17 - Last mean reward per episode: 18.99
# Num timesteps: 942000
# Best mean reward: 49.17 - Last mean reward per episode: 19.09
# Num timesteps: 943000
# Best mean reward: 49.17 - Last mean reward per episode: 19.22
# Num timesteps: 944000
# Best mean reward: 49.17 - Last mean reward per episode: 19.03
# Num timesteps: 945000
# Best mean reward: 49.17 - Last mean reward per episode: 19.05
# Num timesteps: 946000
# Best mean reward: 49.17 - Last mean reward per episode: 19.10
# Num timesteps: 947000
# Best mean reward: 49.17 - Last mean reward per episode: 19.05
# Num timesteps: 948000
# Best mean reward: 49.17 - Last mean reward per episode: 19.00
# Num timesteps: 949000
# Best mean reward: 49.17 - Last mean reward per episode: 19.09
# Num timesteps: 950000
# Best mean reward: 49.17 - Last mean reward per episode: 19.10
# Num timesteps: 951000
# Best mean reward: 49.17 - Last mean reward per episode: 18.97
# Num timesteps: 952000
# Best mean reward: 49.17 - Last mean reward per episode: 18.93
# Num timesteps: 953000
# Best mean reward: 49.17 - Last mean reward per episode: 18.86
# Num timesteps: 954000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 955000
# Best mean reward: 49.17 - Last mean reward per episode: 18.76
# Num timesteps: 956000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 957000
# Best mean reward: 49.17 - Last mean reward per episode: 18.78
# Num timesteps: 958000
# Best mean reward: 49.17 - Last mean reward per episode: 18.79
# Num timesteps: 959000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 960000
# Best mean reward: 49.17 - Last mean reward per episode: 18.74
# Num timesteps: 961000
# Best mean reward: 49.17 - Last mean reward per episode: 18.79
# Num timesteps: 962000
# Best mean reward: 49.17 - Last mean reward per episode: 18.80
# Num timesteps: 963000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 964000
# Best mean reward: 49.17 - Last mean reward per episode: 18.74
# Num timesteps: 965000
# Best mean reward: 49.17 - Last mean reward per episode: 18.79
# Num timesteps: 966000
# Best mean reward: 49.17 - Last mean reward per episode: 18.73
# Num timesteps: 967000
# Best mean reward: 49.17 - Last mean reward per episode: 18.68
# Num timesteps: 968000
# Best mean reward: 49.17 - Last mean reward per episode: 18.67
# Num timesteps: 969000
# Best mean reward: 49.17 - Last mean reward per episode: 18.64
# Num timesteps: 970000
# Best mean reward: 49.17 - Last mean reward per episode: 18.57
# Num timesteps: 971000
# Best mean reward: 49.17 - Last mean reward per episode: 18.59
# Num timesteps: 972000
# Best mean reward: 49.17 - Last mean reward per episode: 18.56
# Num timesteps: 973000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 974000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 975000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 976000
# Best mean reward: 49.17 - Last mean reward per episode: 18.47
# Num timesteps: 977000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 978000
# Best mean reward: 49.17 - Last mean reward per episode: 18.48
# Num timesteps: 979000
# Best mean reward: 49.17 - Last mean reward per episode: 18.49
# Num timesteps: 980000
# Best mean reward: 49.17 - Last mean reward per episode: 18.49
# Num timesteps: 981000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 982000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 983000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 984000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 985000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 986000
# Best mean reward: 49.17 - Last mean reward per episode: 18.50
# Num timesteps: 987000
# Best mean reward: 49.17 - Last mean reward per episode: 18.51
# Num timesteps: 988000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 989000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 990000
# Best mean reward: 49.17 - Last mean reward per episode: 18.55
# Num timesteps: 991000
# Best mean reward: 49.17 - Last mean reward per episode: 18.54
# Num timesteps: 992000
# Best mean reward: 49.17 - Last mean reward per episode: 18.53
# Num timesteps: 993000
# Best mean reward: 49.17 - Last mean reward per episode: 18.52
# Num timesteps: 994000
# Best mean reward: 49.17 - Last mean reward per episode: 18.62
# Num timesteps: 995000
# Best mean reward: 49.17 - Last mean reward per episode: 18.67
# Num timesteps: 996000
# Best mean reward: 49.17 - Last mean reward per episode: 18.72
# Num timesteps: 997000
# Best mean reward: 49.17 - Last mean reward per episode: 18.73
# Num timesteps: 998000
# Best mean reward: 49.17 - Last mean reward per episode: 18.77
# Num timesteps: 999000
# Best mean reward: 49.17 - Last mean reward per episode: 18.79
# Num timesteps: 1000000
# Best mean reward: 49.17 - Last mean reward per episode: 18.70
# Num timesteps: 1001000
# Best mean reward: 49.17 - Last mean reward per episode: 18.68

# %%
print('Total time taken: {} min'.format((end - start)/60))

# %% [markdown]
# ### Inference

# %%
# env.M.flag_=True
env.M.flag_=False
obs=env.reset()
# Out:
# c:\Users\adria\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.M to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.M` for environment variables or `env.get_wrapper_attr('M')` that will search the reminding wrappers.
#   logger.warn(

# %%
obs=obs[0]

# %%
i=0
while i<1000:
    action, _states = model.predict(obs)
    obs, rewards, dones,_, info = env.step(int(action))
#     print(env.tmp, env.const)
    
    if dones:
        break
    i+=1

# %%
print(i)
# Out:
# 49

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
results_plotter.plot_results([log_dir], ts, results_plotter.X_TIMESTEPS, "CantileverEnv")

# %%
obs=env.reset()[0]

# %%
# Load the agent
model_best = PPO.load(log_dir + "/best_model.zip",env=env)

# %%
i=0
while i<1000:
    action, _states = model_best.predict(obs)
    
    obs, rewards, dones, _,info = env.step(int(action))
#     print(env.tmp, env.const)
    if dones:
        break
    i+=1

# %%
i
# Out:
# 49

# %%
env.render()
# Out:
# Final Cantilever beam design:

# %%
# TODO - https://www.sciencedirect.com/science/article/pii/S0264127522002933

# 6 by 6 grid
# different reward 3 
# training ~1.5 hr

# illegal moves reward = -1, terminate ? 

# CNN
# randomize loads 
# utilize symmetry
# reward at the end of episode
# action - remove elements not add 
# refinement 6x6 -> 12x12
# load two elements in inference - test generalizability
# input stress field instead of density field 
# test different RL algorithms

# %%
import random

# %%
for j in range(10):
    i=0
    obs=env.reset()
    while i<16*0.68753125:
        action = random.randint(0, 15)

        env.args = get_args(*mbb_beam(rd=env.rd))

        env.M.action_space_(action, env.x)   
        env.tmp, env.const = fast_stopt(env.args, env.x)
        
        i+=1
    print(env.tmp, env.const)

# %%
for j in range(10):
    i=0
    obs=env.reset()
    while i<9*0.68753125:
        action = random.randint(0, 8)

        env.args = get_args(*mbb_beam(rd=env.rd))

        env.M.action_space_(action, env.x)   
        env.tmp, env.const = fast_stopt(env.args, env.x)
        
        i+=1
    print(env.tmp, env.const)
